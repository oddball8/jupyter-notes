# %% [markdown]
# # jupyter-notes
#
# Notebook containing examples of key jupyter data tasks.

# %% [markdown]
# ## Import Modules

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from scipy import stats
import csv

# %% [markdown]
# ## Read CSV

# %%
#read csv files --- data from fbref
epl_df = pd.read_csv (r'epl.csv')

# %% [markdown]
# ## Scatterplot & Correlation

# %%
x=[]
y=[]

x = epl_df['xGD'].tolist()
y = epl_df['GD'].tolist()

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.title("Relationship between xGD and GD")
plt.xlabel("xGD")
plt.ylabel("GD")
plt.show()

print("Correlation Coefficient:")
print(r)
# Out:
# Correlation Coefficient:
# 0.9403034600786239

# %% [markdown]
# ## Filter Dataframe

# %%
epl_2021_df = epl_df[(epl_df.Season == 2021)]

# %% [markdown]
# ## Calculate Variance of a Column

# %%
epl_2021_var = epl_2021_df.loc[:,"GD"].var()

# %% [markdown]
# ## Scatterplot

# %%
plt.scatter(epl_2021_df.GF, epl_2021_df.GA, label="Premier League")

plt.title("2020/21 Goals For/Goals Against")
plt.xlabel("Goals For")
plt.ylabel("Goals Against")

plt.legend()
plt.show()

# %% [markdown]
# ## Boxplots

# %%
epl_df.boxplot(column='GD',
                  by='Season',
                  color='magenta',
                rot=90)
# Out:
# <AxesSubplot:title={'center':'GD'}, xlabel='Season'>
